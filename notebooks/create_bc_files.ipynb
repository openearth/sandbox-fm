# %%
import mako.template



template = """
# %for i in range(360, 360000, 360):
${i}      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# %endfor
"""

# %%
print(mako.template.Template(text=template).render())
# Out:
# 360      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 720      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 1080      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 1440      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 1800      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 2160      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 2520      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 2880      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 3240      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 3600      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 3960      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 4320      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 4680      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 5040      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# 5400      360.000     1.000   9.14777     0.95819 E_reuse.bcf
# ...

# %%
template = """
# %for i in range(360, 360000, 360):
     ${i}      360.000     1.000   9.14777     0.95819 q_reuse.bcf
# %endfor
"""

# %%
print(mako.template.Template(text=template).render())
# Out:
#      360      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      720      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      1080      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      1440      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      1800      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      2160      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      2520      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      2880      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      3240      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      3600      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      3960      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      4320      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      4680      360.000     1.000   9.14777     0.95819 q_reuse.bcf
#      5040      360.000     1.000   9.14777     0.95819 q_reuse.bcf
# ...

# %%
template = """
# %for i in range(360, 360000, 360):
     ${i}      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
# %endfor
"""

# %%
print(mako.template.Template(text=template).render())
# Out:
#      360      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      720      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      1080      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      1440      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      1800      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      2160      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      2520      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      2880      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      3240      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      3600      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      3960      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      4320      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      4680      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
#      5040      360.000     1.000   9.14777     0.95819 Es_reuse.bcf
# ...
