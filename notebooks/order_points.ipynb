# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cal_pts = np.array([
    [
      589161.3718647438,
      4096037.1884528063
    ],
    [
      589552.7019537461,
      4095739.9397602044
    ],
    [
      589730.9745498472,
      4096064.2110612243
    ],
    [
      589352.6887971449,
      4096339.8416670915
    ]
])

# %%
x = np.array([
        [ 589563.42,  589774.19],
        [ 589149.75,  589360.51]
    ])
y = np.array([[ 4095849.2,  4096150.2],
        [ 4096138.9,  4096439.9]])
mat_pts = np.c_[x.ravel(), y.ravel()][[2, 0, 1, 3], :]

# %%
fig, ax = plt.subplots()
ax.plot(mat_pts[:, 0], mat_pts[:, 1], color='red', label='mat')
for i, pt in enumerate(mat_pts):
    ax.text(pt[0], pt[1], str(i))
ax.plot(cal_pts[:, 0], cal_pts[:, 1], color='blue', label='cal')
for i, pt in enumerate(cal_pts):
    ax.text(pt[0], pt[1], str(i))

# %%
mat_pts.tolist()
# Out:
# [[589149.75, 4096138.9],
#  [589563.42, 4095849.2],
#  [589774.19, 4096150.2],
#  [589360.51, 4096439.9]]
