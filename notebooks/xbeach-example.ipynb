# %%
import numpy as np
import bmi.wrapper

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xbeach = bmi.wrapper.BMIWrapper('xbeach')

# %%
xbeach.initialize('/Users/baart_f/src/sandbox-fm/tests/LargerModel4/params.txt')

# %%
xbeach.get_time_step()
# Out:
# -123.0

# %%
# %%timeit
#for i in range(10):    
xbeach.update(600)

# %%
data = {}
data['ravensburger'] = np.s_[10:60, 10:50]

# hh -> zs - zb
for var in ["zs", "zb", "u", "v", "x", "y", "hh", "H"]:
    data[var] = xbeach.get_var(var)

# %%
plt.imshow(data["hh"][:,:])
plt.colorbar()

# %%
data['zb']
# Out:
# array([[-18.        , -17.99998272, -17.9999174 , ...,  -4.4594769 ,
#          -4.7355161 ,  -4.7355161 ],
#        [-18.        , -17.99998272, -17.9999174 , ...,  -4.4594769 ,
#          -4.7355161 ,  -4.7355161 ],
#        [-18.        , -17.99997002, -17.99988697, ...,  -4.4594769 ,
#          -4.7355161 ,  -4.7355161 ],
#        ...,
#        [-18.        , -17.99951387, -17.99897629, ...,  -1.2843433 ,
#          -1.1597608 ,  -1.1597608 ],
#        [-18.        , -17.99937297, -17.9989065 , ...,  -1.664071  ,
#          -1.5320816 ,  -1.5320816 ],
#        [-18.        , -17.99937297, -17.9989065 , ...,  -1.664071  ,
#          -1.5320816 ,  -1.5320816 ]])

# %%
plt.imshow(data["zb"][:,:])
plt.colorbar()

# %%
plt.imshow(data["H"][:,:])
plt.colorbar()
